# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 1, 500)
s1 = 0.5*np.sin(2 * np.pi * t)
s1 = s1 + 0.5
s1 = np.floor(256 * s1)

# %%
print(f"LDI R16, {int(s1[5])}")
print(f"ST X+, R16\n")
print(f"asdf")
# Out:
# LDI R16, 136
# ST X+, R16
#
# asdf

# %%
plt.plot(s1)

# %%
for i in s1:
    print(f"ldi r16, {int(i)}")
    print(f"st x+, r16")
# Out:
# ldi r16, 128
# st x+, r16
# ldi r16, 129
# st x+, r16
# ldi r16, 131
# st x+, r16
# ldi r16, 132
# st x+, r16
# ldi r16, 134
# st x+, r16
# ldi r16, 136
# st x+, r16
# ldi r16, 137
# st x+, r16
# ldi r16, 139
# st x+, r16
# ldi r16, 140
# st x+, r16
# ldi r16, 142
# st x+, r16
# ldi r16, 144
# st x+, r16
# ldi r16, 145
# st x+, r16
# ldi r16, 147
# st x+, r16
# ldi r16, 148
# st x+, r16
# ldi r16, 150
# st x+, r16
# ldi r16, 152
# st x+, r16
# ldi r16, 153
# st x+, r16
# ldi r16, 155
# st x+, r16
# ldi r16, 156
# st x+, r16
# ldi r16, 158
# st x+, r16
# ldi r16, 159
# st x+, r16
# ldi r16, 161
# st x+, r16
# ldi r16, 163
# st x+, r16
# ldi r16, 164
# st x+, r16
# ldi r16, 166
# st x+, r16
# ldi r16, 167
# st x+, r16
# ldi r16, 169
# st x+, r16
# ldi r16, 170
# st x+, r16
# ldi r16, 172
# st x+, r16
# ldi r16, 173
# st x+, r16
# ldi r16, 175
# st x+, r16
# ldi r16, 176
# st x+, r16
# ldi r16, 178
# st x+, r16
# ldi r16, 179
# st x+, r16
# ldi r16, 181
# st x+, r16
# ldi r16, 182
# ...
